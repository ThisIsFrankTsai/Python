# %%
import csv
from sqlalchemy import create_engine

with open('2018_kh_data.csv', 'r') as f:
    cr = csv.reader(f)
    data_list = list(cr)

mysql_db_url = 'mysql+pymysql://root:password@206.189.86.205:32769/testdb'
my_db = create_engine(mysql_db_url)
table_name = 'Frank_2018_kh_data0903_02'
# 我們把tsp, pm10, lead都記下來
sql_cmd_str = "CREATE TABLE IF NOT EXISTS %s(sid varchar(20),dtime varchar(20),tsp float,pm10 float,lead float,Dust float,PRIMARY KEY(sid, dtime))" %(table_name)
#插入兩個PRIMARY KEY(sid, dtime) 可以插入兩個同樣名子 但是不同日期的資料
resultProxy = my_db.execute(sql_cmd_str)
#方法一
# 做upsert操作
# for item in data_list[1:]:#因為前面第一row 為 欄位名稱 我們要捨棄掉
#     sid = item[0]#['Name']
#     dtime = item[1]#['Date']
#     tsp = item[2]#['TSP']
#     dust=item[-1] #Dust
#     pm10 = item[3]#['PM10']
#     lead = item[7]#['Lead']
#     sql_cmd_str = "insert into %s (sid, dtime, tsp, pm10, lead,dust) values('%s', '%s', '%s', '%s', '%s','%s')" %(
#         table_name, sid, dtime, tsp, pm10, lead,dust)
#     sql_cmd_str = sql_cmd_str + (" ON DUPLICATE KEY UPDATE tsp='%s', pm10='%s', lead='%s,dust='%s'" %(tsp, pm10, lead,dust))
#     print(sql_cmd_str)
#方法二
for item in data_list[1:]:
    sid = item[0]#['Name']
    dtime = item[1]#['Date']
    tsp = item[2]#['TSP']
    dust=item[-1] #['dust']
    
    if tsp=='':
        tsp = 'NULL'
    pm10 = item[3]#['PM10']
    if pm10=='':
        pm10 = 'NULL'
    lead = item[7]#['Lead']
    if lead=='':
        lead = 'NULL'
    
    if dust=='':
        dust= 'NULL'
    
    sql_cmd_str = "insert into %s (sid, dtime, tsp, pm10, lead,dust) values('%s', '%s', %s, %s, %s,%s)" %(table_name, sid, dtime, tsp, pm10, lead,dust)#%s 單引號拿掉 因為為null資訊
    sql_cmd_str = sql_cmd_str + (" ON DUPLICATE KEY UPDATE tsp=%s, pm10=%s, lead=%s,dust=%s" %(tsp, pm10, lead,dust))
    resultProxy=my_db.execute(sql_cmd_str)
    print(sql_cmd_str)
# Out:
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('大社工業區', '2018年1月', 93, NULL, 0.029,3.6) ON DUPLICATE KEY UPDATE tsp=93, pm10=NULL, lead=0.029,dust=3.6
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('大寮區公所', '2018年1月', 79, NULL, 0.042,1.54) ON DUPLICATE KEY UPDATE tsp=79, pm10=NULL, lead=0.042,dust=1.54
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('大樹監測站', '2018年1月', 61, NULL, 0.02,1.18) ON DUPLICATE KEY UPDATE tsp=61, pm10=NULL, lead=0.02,dust=1.18
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('仁武國中', '2018年1月', 79, NULL, 0.058,2.68) ON DUPLICATE KEY UPDATE tsp=79, pm10=NULL, lead=0.058,dust=2.68
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('半屏山電信局', '2018年1月', 104, 67, 0.014,1.21) ON DUPLICATE KEY UPDATE tsp=104, pm10=67, lead=0.014,dust=1.21
# ...

# %%
# 找出某個站的資料: where
sid = '左營國小'
sql_cmd_str = "select * from %s where sid='%s'" %(table_name, sid)
resultProxy=my_db.execute(sql_cmd_str)
data = resultProxy.fetchall()
print('-- data --')
#print(data)
for item in data:
    my_dict_data=dict(item) #轉成dict，原本為db資料
    print(my_dict_data)
# Out:
# -- data --
# {'sid': '左營國小', 'dtime': '2018年10月', 'tsp': 89.0, 'pm10': 51.0, 'lead': 0.024, 'Dust': 2.15}
# {'sid': '左營國小', 'dtime': '2018年11月', 'tsp': 65.0, 'pm10': 38.0, 'lead': 0.035, 'Dust': 1.79}
# {'sid': '左營國小', 'dtime': '2018年12月', 'tsp': 90.0, 'pm10': 52.0, 'lead': 0.019, 'Dust': 2.18}
# {'sid': '左營國小', 'dtime': '2018年1月', 'tsp': 98.0, 'pm10': 64.0, 'lead': 0.006, 'Dust': 1.13}
# {'sid': '左營國小', 'dtime': '2018年2月', 'tsp': 59.0, 'pm10': 32.0, 'lead': 0.017, 'Dust': 1.5}
# {'sid': '左營國小', 'dtime': '2018年3月', 'tsp': 54.0, 'pm10': 36.0, 'lead': 0.068, 'Dust': 1.55}
# {'sid': '左營國小', 'dtime': '2018年4月', 'tsp': 61.0, 'pm10': 33.0, 'lead': 0.028, 'Dust': 1.48}
# {'sid': '左營國小', 'dtime': '2018年5月', 'tsp': 49.0, 'pm10': 38.0, 'lead': 0.047, 'Dust': 4.69}
# {'sid': '左營國小', 'dtime': '2018年6月', 'tsp': 22.0, 'pm10': 16.0, 'lead': 0.034, 'Dust': 1.47}
# {'sid': '左營國小', 'dtime': '2018年7月', 'tsp': 37.0, 'pm10': 16.0, 'lead': 0.022, 'Dust': 1.23}
# ...

# %%
# 找出某個站的資料, 並排序: where, order: ASC:順向由小到大, DESC:反向 由大到小
sid = '左營國小'
sql_cmd_str = "select * from %s where sid='%s' order by dtime ASC" %(table_name, sid) #錯誤,因為比較的dtime為字串
resultProxy=my_db.execute(sql_cmd_str)
data = resultProxy.fetchall()
print('-- data --')
print(data)
# Out:
# -- data --
# ...

# %%
# 先把資料都刪掉: DELETE FROM table_name
sql_cmd_str = "DELETE FROM %s" %(table_name)
resultProxy=my_db.execute(sql_cmd_str)

# %%
# 做upsert操作: 試著改時間格式
import datetime
import random

for item in data_list[1:]:
    sid = item[0]#['Name']
    dtime = item[1]#['Date']
    dtime = dtime.replace('月', '')
    dtime_tmp = dtime.split('年')
    dtime = '%s-%02d' %(dtime_tmp[0], int(dtime_tmp[1])) #格式化月轉成兩位數
    tsp = item[2]#['TSP']
    if tsp=='':
        tsp = 'NULL'
    pm10 = item[3]#['PM10']
    if pm10=='':
        pm10 = 'NULL'
    lead = item[7]#['Lead']
    if lead=='':
        lead = 'NULL'
    if dust=='':
        dust='NULL'
    
    sql_cmd_str = "insert into %s (sid, dtime, tsp, pm10, lead,dust) values('%s', '%s', %s, %s, %s,%s)" %(
        table_name, sid, dtime, tsp, pm10, lead,dust)
    sql_cmd_str = sql_cmd_str + (" ON DUPLICATE KEY UPDATE tsp=%s, pm10=%s, lead=%s,dust=%s" %(tsp, pm10, lead,dust))
    resultProxy=my_db.execute(sql_cmd_str)
    print(sql_cmd_str)
# Out:
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('大社工業區', '2018-01', 93, NULL, 0.029,2.07) ON DUPLICATE KEY UPDATE tsp=93, pm10=NULL, lead=0.029,dust=2.07
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('大寮區公所', '2018-01', 79, NULL, 0.042,2.07) ON DUPLICATE KEY UPDATE tsp=79, pm10=NULL, lead=0.042,dust=2.07
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('大樹監測站', '2018-01', 61, NULL, 0.02,2.07) ON DUPLICATE KEY UPDATE tsp=61, pm10=NULL, lead=0.02,dust=2.07
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('仁武國中', '2018-01', 79, NULL, 0.058,2.07) ON DUPLICATE KEY UPDATE tsp=79, pm10=NULL, lead=0.058,dust=2.07
# insert into Frank_2018_kh_data0903_02 (sid, dtime, tsp, pm10, lead,dust) values('半屏山電信局', '2018-01', 104, 67, 0.014,2.07) ON DUPLICATE KEY UPDATE tsp=104, pm10=67, lead=0.014,dust=2.07
# ...

# %%
# 找出某個站的資料, 並排序: where, order
sid = '左營國小'
sql_cmd_str = "select * from %s where sid='%s' order by dtime DESC" %(table_name, sid)
resultProxy=my_db.execute(sql_cmd_str)
data = resultProxy.fetchall()
print('-- data --')
#print(data)
for item in data:
    print(item)
# Out:
# -- data --
# ('左營國小', '2018-12', 90.0, 52.0, 0.019, 2.07)
# ('左營國小', '2018-11', 65.0, 38.0, 0.035, 2.07)
# ('左營國小', '2018-10', 89.0, 51.0, 0.024, 2.07)
# ('左營國小', '2018-09', 32.0, 22.0, 0.02, 2.07)
# ('左營國小', '2018-08', 22.0, 14.0, 0.004, 2.07)
# ('左營國小', '2018-07', 37.0, 16.0, 0.022, 2.07)
# ('左營國小', '2018-06', 22.0, 16.0, 0.034, 2.07)
# ('左營國小', '2018-05', 49.0, 38.0, 0.047, 2.07)
# ('左營國小', '2018-04', 61.0, 33.0, 0.028, 2.07)
# ('左營國小', '2018-03', 54.0, 36.0, 0.068, 2.07)
# ('左營國小', '2018-02', 59.0, 32.0, 0.017, 2.07)
# ('左營國小', '2018-01', 98.0, 64.0, 0.006, 2.07)

# %%
# 找Dust>3的站 並排序: where, order
sid = '大寮區公所'
sql_cmd_str = "select * from %s where  dust>'1' order by dust ASC" %(table_name)
resultProxy=my_db.execute(sql_cmd_str)
data = resultProxy.fetchall()
print('-- data --')
for item in data:
    print(item)
# Out:
# -- data --
# ('莊敬國小', '2018-12', 110.0, 83.0, 0.031, 2.07)
# ('環保局環境檢驗科', '2018-08', 26.0, 13.0, 0.017, 2.07)
# ('環保局環境檢驗科', '2018-07', 37.0, 18.0, 0.04, 2.07)
# ('環保局環境檢驗科', '2018-06', 38.0, 21.0, 0.02, 2.07)
# ('環保局環境檢驗科', '2018-05', 44.0, 23.0, 0.029, 2.07)
# ('環保局環境檢驗科', '2018-04', 74.0, 38.0, 0.044, 2.07)
# ('環保局環境檢驗科', '2018-03', 59.0, 38.0, 0.066, 2.07)
# ('環保局環境檢驗科', '2018-02', 76.0, 46.0, 0.017, 2.07)
# ('環保局環境檢驗科', '2018-01', 92.0, 58.0, 0.02, 2.07)
# ('河濱國小', '2018-12', 97.0, 57.0, 0.005, 2.07)
# ('河濱國小', '2018-11', 84.0, 42.0, 0.022, 2.07)
# ('河濱國小', '2018-10', 100.0, 60.0, 0.058, 2.07)
# ('河濱國小', '2018-09', 27.0, 16.0, 0.006, 2.07)
# ('環保局環境檢驗科', '2018-09', 30.0, 13.0, 0.006, 2.07)
# ('環保局環境檢驗科', '2018-10', 104.0, 51.0, 0.071, 2.07)
# ('環保局環境檢驗科', '2018-11', 78.0, 36.0, 0.028, 2.07)
# ('莊敬國小', '2018-11', 77.0, 52.0, 0.03, 2.07)
# ('莊敬國小', '2018-10', 98.0, 69.0, 0.076, 2.07)
# ('莊敬國小', '2018-09', 22.0, 17.0, 0.015, 2.07)
# ('莊敬國小', '2018-08', 21.0, 18.0, 0.018, 2.07)
# ...

# %%
#開始畫圖，以lead 作圖
import matplotlib.pyplot as plt

dust_list = []
dtime_list = []
lead_list = []
for item in data:
    dust_list.append(item['Dust'])
    lead_list.append(item['lead'])
    dtime_list.append(item['dtime'])
    
plt.plot(dtime_list, lead_list)
plt.xlabel('month')
plt.ylabel('TSP')
plt.xticks(dtime_list, rotation=90)
plt.grid()

# %%
tsp_list
# Out:
# [90.0, 65.0, 89.0, 32.0, 22.0, 37.0, 22.0, 49.0, 61.0, 54.0, 59.0, 98.0]

# %%
#資料為None、Null 會無法作圖

tsp_list[2]=None 
plt.plot(dtime_list, tsp_list)
plt.xlabel('month')
plt.ylabel('TSP')
plt.xticks(dtime_list, rotation=90)
plt.grid()

# %%
#資料為0可能造成判斷失誤

tsp_list[2]=0 
plt.plot(dtime_list, tsp_list)
plt.xlabel('month')
plt.ylabel('TSP')
plt.xticks(dtime_list, rotation=90)
plt.grid()
