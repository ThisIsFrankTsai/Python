# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.request
import os 

class new:
    def __init__(self,):
        pass
    
    def mkdir_(self,path):
        if not os.path.exists(path):
            os.makedirs(path)

    def news_crl(self,img_lim=10):
        url =  'https://www.ettoday.net/news/hot-news.htm'
        headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}

        res = requests.get(url , headers = headers)
        res.text
        soup = BeautifulSoup(res.text , 'html.parser')
        soup  #變成soup 就可以啟動找盒子的功能
        boxs = soup.find_all('div',class_='piece clearfix')
        # title    = boxs[2].find('img').get('title')
        # img_link = boxs[2].find('img').get('data-original')
        # print(title)
        # print(img_link)
        title_list =[]
        img_list = []
        for box in boxs:
            try:
                title    = box.find('img').get('title')
                if title == None:
                    break
                img_link = box.find('img').get('data-original')
                title_list.append(title)
                if len(title_list)==img_lim+1:
                    break
                img_list .append(img_link)
                print(title)
                print(img_link)
                print('======================================')
                time.sleep(0.01)
            except:
                break

        n=0   
        for link in img_list:
            L = 'https:'+ link
            urllib.request.urlretrieve(L,f'./0115/{n}.jpg')
            n=n+1
N=new()
N.mkdir_('./0115')
N.news_crl(20)

# %%
N=new()
N.mkdir_('./0115')
N.news_crl(20)
# Out:
# 百萬網美「性愛片瘋傳」曝悲慘身世！揹千萬債：用身體才可能還清
# //cdn2.ettoday.net/images/6129/c6129022.jpg
# ======================================
# 男大生偷騎同學26萬黃牌重機　失控自撞爆頭亡…最後身影曝
# //cdn2.ettoday.net/images/6129/c6129371.jpg
# ======================================
# 精準預言本土病例下降！名醫曝2個月後「迎接新世界」：再努力一下
# //cdn2.ettoday.net/images/6126/c6126913.jpg
# ======================================
# 水逆來了！唐綺陽點名「4星座」首當其衝　警示：將有戲劇性逆轉
# //cdn2.ettoday.net/images/6088/c6088266.jpg
# ======================================
# 15年懸案突破了！女友和阿嬤都失蹤　妹控學霸哥藏10多顆人齒
# //cdn2.ettoday.net/images/6128/c6128119.jpg
# ======================================
# 日月光辣妹「Turn口罩」正臉曝光　IG被起底！20字大方回應
# //cdn2.ettoday.net/images/6129/c6129010.jpg
# ======================================
# 好市多「地獄級雷物」曝光　她氣奔退貨！苦主狂+1：超像喝洗潔劑
# //cdn2.ettoday.net/images/5752/c5752442.jpg
# ======================================
# 清純女星遭逼下海拍片！拒演「慘被打斷肋骨」引退　消失25年近況曝
# //cdn2.ettoday.net/images/6129/c6129455.jpg
# ======================================
# 正妹新娘迎親挑逗熱舞　新郎暴怒一把推飛「不娶了！」
# //cdn2.ettoday.net/images/6128/c6128407.jpg
# ======================================
# 周杰倫MV最正女主角？鄉民認證「她」狂飄仙氣：顏值巔峰
# //cdn2.ettoday.net/images/5614/c5614052.jpg
# ======================================
# 快訊／西堤群聚延燒！晚間驚傳再+3人確診　2學生被採檢站篩出
# //cdn2.ettoday.net/images/6127/c6127646.jpg
# ======================================
# 男生開雙B或TOYOTA「女生會在意嗎」？網揭一關鍵：遇這種要珍惜
# //cdn2.ettoday.net/images/6096/c6096405.jpg
# ======================================
# 快訊／桃園男大生「借朋友重機」自撞　口鼻「流腦脊液」亡
# //cdn2.ettoday.net/images/6128/c6128903.jpg
# ======================================
# 台中最任性阿公！　沙鹿地主花3.5億打造孫子遊樂場
# //cdn2.ettoday.net/images/6127/c6127274.jpg
# ======================================
# 水逆來了！4星座逆風迎接超強好運　「工作+桃花+財運」飆升
# //cdn2.ettoday.net/images/5598/c5598885.jpg
# ======================================
# 快訊／桃園+6！西堤3顧客、3學生確診　鄭文燦：擴大採檢600人
# //cdn2.ettoday.net/images/6129/c6129160.jpg
# ======================================
# 快訊／殉職飛官想回家了！父母女友含淚招魂　妹妹一次就聖筊
# //cdn2.ettoday.net/images/6129/c6129441.jpg
# ======================================
# 超商領包裹「1規定」變了！　網購族超有感：真的快很多
# //cdn2.ettoday.net/images/4517/c4517326.jpg
# ======================================
# Keanna澄清「天大的誤會」！ØZI經紀人解釋2人關係：謝謝她的欣賞
# //cdn2.ettoday.net/images/6128/c6128896.jpg
# ======================================
# 快訊／F-16V墜海組織DNA比對出爐！　確認是飛官陳奕本人
# //cdn2.ettoday.net/images/6123/c6123009.jpg
# ======================================
